# %% [markdown]
# <a href="https://colab.research.google.com/github/Naf006/Satellite-Image-Segmentation/blob/main/Unet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install patchify
# Out:
# Collecting patchify
#   Downloading patchify-0.2.3-py3-none-any.whl (6.6 kB)
# Requirement already satisfied: numpy<2,>=1 in /usr/local/lib/python3.10/dist-packages (from patchify) (1.25.2)
# Installing collected packages: patchify
# Successfully installed patchify-0.2.3

# %%
import os
import cv2
from PIL import Image
import numpy as np
from patchify import patchify
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from matplotlib import pyplot as plt
import random

# %%
minmaxscaler = MinMaxScaler()

# %%
dataset_root_folder="/content/drive/MyDrive/"

# %%
dataset_name = "Semantic segmentation dataset"

# %%
#for img preprocessing
image_patch_size = 256

# %%
for path, subdirs, files in os.walk(os.path.join(dataset_root_folder,dataset_name)):
  dir_name= path.split(os.path.sep)[-1]
  if dir_name == 'masks':
    images= os.listdir(path)
    print(path)
    for i, image_name in enumerate(images):
      if (image_name.endswith('.png')):
        a= True
# Out:
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 7/masks
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 8/masks
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 4/masks
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 6/masks
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 3/masks
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 5/masks
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 2/masks
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 1/masks

# %%
image_dataset = []
mask_dataset = []

for image_type in ['images' , 'masks']:
  if image_type == 'images':
    image_extension = 'jpg'
  elif image_type == 'masks':
     image_extension = 'png'
  for tile_id in range(1,8):
    for image_id in range(1,20):
      image = cv2.imread(f'{dataset_root_folder}/{dataset_name}/Tile {tile_id}/{image_type}/image_part_00{image_id}.{image_extension}',1)
      if image is not None:
        if image_type == 'masks':
          image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        #print(image.shape)
        size_x = (image.shape[1]//image_patch_size)*image_patch_size
        size_y = (image.shape[0]//image_patch_size)*image_patch_size
        #print("{} --- {} - {}".format(image.shape, size_x, size_y))
        image = Image.fromarray(image)
        image = image.crop((0,0, size_x, size_y))
        #print("({},  {})".format(image.size[0],image.size[1]))
        image = np.array(image)
        patched_images = patchify(image, (image_patch_size, image_patch_size, 3), step=image_patch_size)
        #print(len(patched_images))
        for i in range(patched_images.shape[0]):
          for j in range(patched_images.shape[1]):
            if image_type == 'images':
              individual_patched_image = patched_images[i,j,:,:]
              #print(individual_patched_image.shape)
              individual_patched_image = minmaxscaler.fit_transform(individual_patched_image.reshape(-1, individual_patched_image.shape[-1])).reshape(individual_patched_image.shape)
              individual_patched_image = individual_patched_image[0]
              #print(individual_patched_image.shape)
              image_dataset.append(individual_patched_image)
            elif image_type == 'masks':
              individual_patched_mask = patched_images[i,j,:,:]
              individual_patched_mask = individual_patched_mask[0]
              mask_dataset.append(individual_patched_mask)

# %%
image_dataset = np.array(image_dataset[:500])
mask_dataset =  np.array(mask_dataset[:500])

# %%
print(len(image_dataset))
print(len(mask_dataset))
# Out:
# 500
# 500

# %%
class_building = '#3C1098'
class_building = class_building.lstrip('#')
class_building = np.array(tuple(int(class_building[i:i+2], 16) for i in (0,2,4)))
print(class_building)

class_land = '#8429F6'
class_land = class_land.lstrip('#')
class_land = np.array(tuple(int(class_land[i:i+2], 16) for i in (0,2,4)))
print(class_land)

class_road = '#6EC1E4'
class_road = class_road.lstrip('#')
class_road = np.array(tuple(int(class_road[i:i+2], 16) for i in (0,2,4)))
print(class_road)

class_vegetation = '#FEDD3A'
class_vegetation = class_vegetation.lstrip('#')
class_vegetation = np.array(tuple(int(class_vegetation[i:i+2], 16) for i in (0,2,4)))
print(class_vegetation)

class_water = '#E2A929'
class_water = class_water.lstrip('#')
class_water = np.array(tuple(int(class_water[i:i+2], 16) for i in (0,2,4)))
print(class_water)

class_unlabeled = '#9B9B9B'
class_unlabeled = class_unlabeled.lstrip('#')
class_unlabeled = np.array(tuple(int(class_unlabeled[i:i+2], 16) for i in (0,2,4)))
print(class_unlabeled)
# Out:
# [ 60  16 152]
# [132  41 246]
# [110 193 228]
# [254 221  58]
# [226 169  41]
# [155 155 155]

# %%
label = individual_patched_mask

# %%
def rgb_to_label(label):
  label_segment = np.zeros(label.shape, dtype=np.uint8)
  label_segment[np.all(label == class_water, axis=-1)] = 0
  label_segment[np.all(label == class_land, axis=-1)] = 1
  label_segment[np.all(label == class_road, axis=-1)] = 2
  label_segment[np.all(label == class_building, axis=-1)] = 3
  label_segment[np.all(label == class_vegetation, axis=-1)] = 4
  label_segment[np.all(label == class_unlabeled, axis=-1)] = 5
  #print(label_segment)
  label_segment = label_segment[:,:,0]
  #print(label_segment)
  return label_segment

# %%
labels = []
for mask in mask_dataset:
    label = rgb_to_label(mask)
    labels.append(label)

# %%
labels = np.array(labels)
labels = np.expand_dims(labels, axis=3)

# %%
np.unique(labels)
# Out:
# array([0, 1, 2, 3, 4, 5], dtype=uint8)

# %%
print("Total unique labels based on masks: ",format(np.unique(labels)))
# Out:
# Total unique labels based on masks:  [0 1 2 3 4 5]

# %%
random_image_id = random.randint(0, len(image_dataset))

plt.figure(figsize=(14,8))
plt.subplot(121)
plt.imshow(image_dataset[random_image_id])
plt.subplot(122)
#plt.imshow(mask_dataset[random_image_id])
plt.imshow(labels[random_image_id][:,:,0])

# %%
total_classes = len(np.unique(labels))

# %%
from tensorflow.keras.utils import to_categorical
labels_categorical_dataset = to_categorical(labels, num_classes=total_classes)

# %%
master_trianing_dataset = image_dataset
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(master_trianing_dataset, labels_categorical_dataset, test_size=0.20, random_state=42)

# %%
import numpy as np

# Assuming X_train, X_test, y_train, y_test are lists
X_train = np.array(X_train)
X_test = np.array(X_test)
y_train = np.array(y_train)
y_test = np.array(y_test)

# Now you can print their shapes
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (400, 256, 256, 3)
# (100, 256, 256, 3)
# (400, 256, 256, 6)
# (100, 256, 256, 6)

# %%
image_height = X_train.shape[1]
image_width = X_train.shape[2]
image_channels = X_train.shape[3]
total_classes = y_train.shape[3]

# %%
print(image_height)
print(image_width)
print(image_channels)
print(total_classes)
# Out:
# 256
# 256
# 3
# 6

# %%
from keras.models import Model
from keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, Conv2DTranspose
from keras.layers import concatenate, BatchNormalization, Dropout, Lambda
from keras import backend as K

# %%
def jaccard_coef(y_true, y_pred):
  y_true_flatten = K.flatten(y_true)
  y_pred_flatten = K.flatten(y_pred)
  intersection = K.sum(y_true_flatten * y_pred_flatten)
  final_coef_value = (intersection + 1.0) / (K.sum(y_true_flatten) + K.sum(y_pred_flatten) - intersection + 1.0)
  return final_coef_value

# %%
def multi_unet_model(n_classes=6, image_height=256, image_width=256, image_channels=1):

  inputs = Input((image_height, image_width, image_channels))

  source_input = inputs

  c1 = Conv2D(16, (3,3), activation="relu", kernel_initializer="he_normal", padding="same")(source_input)
  c1 = Dropout(0.2)(c1)
  c1 = Conv2D(16, (3,3), activation="relu", kernel_initializer="he_normal", padding="same")(c1)
  p1 = MaxPooling2D((2,2))(c1)

  c2 = Conv2D(32, (3,3), activation="relu", kernel_initializer="he_normal", padding="same")(p1)
  c2 = Dropout(0.2)(c2)
  c2 = Conv2D(32, (3,3), activation="relu", kernel_initializer="he_normal", padding="same")(c2)
  p2 = MaxPooling2D((2,2))(c2)

  c3 = Conv2D(64, (3,3), activation="relu", kernel_initializer="he_normal", padding="same")(p2)
  c3 = Dropout(0.2)(c3)
  c3 = Conv2D(64, (3,3), activation="relu", kernel_initializer="he_normal", padding="same")(c3)
  p3 = MaxPooling2D((2,2))(c3)

  c4 = Conv2D(128, (3,3), activation="relu", kernel_initializer="he_normal", padding="same")(p3)
  c4 = Dropout(0.2)(c4)
  c4 = Conv2D(128, (3,3), activation="relu", kernel_initializer="he_normal", padding="same")(c4)
  p4 = MaxPooling2D((2,2))(c4)

  c5 = Conv2D(256, (3,3), activation="relu", kernel_initializer="he_normal", padding="same")(p4)
  c5 = Dropout(0.2)(c5)
  c5 = Conv2D(256, (3,3), activation="relu", kernel_initializer="he_normal", padding="same")(c5)

  u6 = Conv2DTranspose(128, (2,2), strides=(2,2), padding="same")(c5)
  u6 = concatenate([u6, c4])
  c6 = Conv2D(128, (3,3), activation="relu", kernel_initializer="he_normal", padding="same")(u6)
  c6 = Dropout(0.2)(c6)
  c6 = Conv2D(128, (3,3), activation="relu", kernel_initializer="he_normal", padding="same")(c6)

  u7 = Conv2DTranspose(64, (2,2), strides=(2,2), padding="same")(c6)
  u7 = concatenate([u7, c3])
  c7 = Conv2D(64, (3,3), activation="relu", kernel_initializer="he_normal", padding="same")(u7)
  c7 = Dropout(0.2)(c7)
  c7 = Conv2D(64, (3,3), activation="relu", kernel_initializer="he_normal", padding="same")(c7)

  u8 = Conv2DTranspose(32, (2,2), strides=(2,2), padding="same")(c7)
  u8 = concatenate([u8, c2])
  c8 = Conv2D(32, (3,3), activation="relu", kernel_initializer="he_normal", padding="same")(u8)
  c8 = Dropout(0.2)(c8)
  c8 = Conv2D(32, (3,3), activation="relu", kernel_initializer="he_normal", padding="same")(c8)

  u9 = Conv2DTranspose(16, (2,2), strides=(2,2), padding="same")(c8)
  u9 = concatenate([u9, c1], axis=3)
  c9 = Conv2D(16, (3,3), activation="relu", kernel_initializer="he_normal", padding="same")(u9)
  c9 = Dropout(0.2)(c9)
  c9 = Conv2D(16, (3,3), activation="relu", kernel_initializer="he_normal", padding="same")(c9)

  outputs = Conv2D(n_classes, (1,1), activation="softmax")(c9)

  model = Model(inputs=[inputs], outputs=[outputs])
  return model

# %%
metrics = ["accuracy", jaccard_coef]

# %%
def get_deep_learning_model():
  return multi_unet_model(n_classes=total_classes,
                          image_height=image_height,
                          image_width=image_width,
                          image_channels=image_channels)

# %%
model = get_deep_learning_model()

# %%
import tensorflow as tf
tf.keras.backend.clear_session()
model.compile(optimizer="adam", loss='categorical_crossentropy', metrics=metrics)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 256, 256, 3)]        0         []
#
#  conv2d (Conv2D)             (None, 256, 256, 16)         448       ['input_1[0][0]']
#
#  dropout (Dropout)           (None, 256, 256, 16)         0         ['conv2d[0][0]']
#
#  conv2d_1 (Conv2D)           (None, 256, 256, 16)         2320      ['dropout[0][0]']
#
#  max_pooling2d (MaxPooling2  (None, 128, 128, 16)         0         ['conv2d_1[0][0]']
#  D)
#
#  conv2d_2 (Conv2D)           (None, 128, 128, 32)         4640      ['max_pooling2d[0][0]']
#
#  dropout_1 (Dropout)         (None, 128, 128, 32)         0         ['conv2d_2[0][0]']
#
#  conv2d_3 (Conv2D)           (None, 128, 128, 32)         9248      ['dropout_1[0][0]']
#
#  max_pooling2d_1 (MaxPoolin  (None, 64, 64, 32)           0         ['conv2d_3[0][0]']
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 64, 64, 64)           18496     ['max_pooling2d_1[0][0]']
#
#  dropout_2 (Dropout)         (None, 64, 64, 64)           0         ['conv2d_4[0][0]']
#
#  conv2d_5 (Conv2D)           (None, 64, 64, 64)           36928     ['dropout_2[0][0]']
#
#  max_pooling2d_2 (MaxPoolin  (None, 32, 32, 64)           0         ['conv2d_5[0][0]']
#  g2D)
#
#  conv2d_6 (Conv2D)           (None, 32, 32, 128)          73856     ['max_pooling2d_2[0][0]']
#
#  dropout_3 (Dropout)         (None, 32, 32, 128)          0         ['conv2d_6[0][0]']
#
#  conv2d_7 (Conv2D)           (None, 32, 32, 128)          147584    ['dropout_3[0][0]']
#
#  max_pooling2d_3 (MaxPoolin  (None, 16, 16, 128)          0         ['conv2d_7[0][0]']
#  g2D)
#
#  conv2d_8 (Conv2D)           (None, 16, 16, 256)          295168    ['max_pooling2d_3[0][0]']
#
#  dropout_4 (Dropout)         (None, 16, 16, 256)          0         ['conv2d_8[0][0]']
#
#  conv2d_9 (Conv2D)           (None, 16, 16, 256)          590080    ['dropout_4[0][0]']
#
#  conv2d_transpose (Conv2DTr  (None, 32, 32, 128)          131200    ['conv2d_9[0][0]']
#  anspose)
#
#  concatenate (Concatenate)   (None, 32, 32, 256)          0         ['conv2d_transpose[0][0]',
#                                                                      'conv2d_7[0][0]']
#
#  conv2d_10 (Conv2D)          (None, 32, 32, 128)          295040    ['concatenate[0][0]']
#
#  dropout_5 (Dropout)         (None, 32, 32, 128)          0         ['conv2d_10[0][0]']
#
#  conv2d_11 (Conv2D)          (None, 32, 32, 128)          147584    ['dropout_5[0][0]']
#
#  conv2d_transpose_1 (Conv2D  (None, 64, 64, 64)           32832     ['conv2d_11[0][0]']
#  Transpose)
#
#  concatenate_1 (Concatenate  (None, 64, 64, 128)          0         ['conv2d_transpose_1[0][0]',
#  )                                                                   'conv2d_5[0][0]']
#
#  conv2d_12 (Conv2D)          (None, 64, 64, 64)           73792     ['concatenate_1[0][0]']
#
#  dropout_6 (Dropout)         (None, 64, 64, 64)           0         ['conv2d_12[0][0]']
#
#  conv2d_13 (Conv2D)          (None, 64, 64, 64)           36928     ['dropout_6[0][0]']
#
#  conv2d_transpose_2 (Conv2D  (None, 128, 128, 32)         8224      ['conv2d_13[0][0]']
#  Transpose)
#
#  concatenate_2 (Concatenate  (None, 128, 128, 64)         0         ['conv2d_transpose_2[0][0]',
#  )                                                                   'conv2d_3[0][0]']
#
#  conv2d_14 (Conv2D)          (None, 128, 128, 32)         18464     ['concatenate_2[0][0]']
#
#  dropout_7 (Dropout)         (None, 128, 128, 32)         0         ['conv2d_14[0][0]']
#
#  conv2d_15 (Conv2D)          (None, 128, 128, 32)         9248      ['dropout_7[0][0]']
#
#  conv2d_transpose_3 (Conv2D  (None, 256, 256, 16)         2064      ['conv2d_15[0][0]']
#  Transpose)
#
#  concatenate_3 (Concatenate  (None, 256, 256, 32)         0         ['conv2d_transpose_3[0][0]',
#  )                                                                   'conv2d_1[0][0]']
#
#  conv2d_16 (Conv2D)          (None, 256, 256, 16)         4624      ['concatenate_3[0][0]']
#
#  dropout_8 (Dropout)         (None, 256, 256, 16)         0         ['conv2d_16[0][0]']
#
#  conv2d_17 (Conv2D)          (None, 256, 256, 16)         2320      ['dropout_8[0][0]']
#
#  conv2d_18 (Conv2D)          (None, 256, 256, 6)          102       ['conv2d_17[0][0]']
#
# ==================================================================================================
# Total params: 1941190 (7.41 MB)
# Trainable params: 1941190 (7.41 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.callbacks import ModelCheckpoint,EarlyStopping,ReduceLROnPlateau

# %%
model_filepath = "/content/drive/MyDrive/saved_models/cusunet4.hdf5"
checkpoint = ModelCheckpoint(
    filepath=model_filepath,
    monitor='val_accuracy',
    mode='max',
    save_best_only=True,
    verbose=1
)
earlystop = EarlyStopping(
    monitor = 'val_loss',
    min_delta = 0.001,
    patience = 10,
    mode = 'auto',
    verbose = 1,
    restore_best_weights = True
)

# %%
history_a = model_history

# %%
loss = history_a.history['loss']
val_loss = history_a.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label="Training Loss")
plt.plot(epochs, val_loss, 'r', label="Validation Loss")
plt.title("Training Vs Validation Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %%
jaccard_coef = history_a.history['jaccard_coef']
val_jaccard_coef = history_a.history['val_jaccard_coef']

epochs = range(1, len(jaccard_coef) + 1)
plt.plot(epochs, jaccard_coef, 'y', label="Training IoU")
plt.plot(epochs, val_jaccard_coef, 'r', label="Validation IoU")
plt.title("Training Vs Validation IoU")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %%
import tensorflow.keras.backend as K
from sklearn.metrics import precision_score, recall_score, f1_score

def precision(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

def recall(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

def f1(y_true, y_pred):
    p = precision(y_true, y_pred)
    r = recall(y_true, y_pred)
    f1_score = 2 * ((p * r) / (p + r + K.epsilon()))
    return f1_score

# %%
model_history = saved_model.fit(X_train, y_train,
                          batch_size=8,  # Adjust batch size
                          verbose=1,
                          epochs=100,
                          validation_data=(X_test, y_test),
                          callbacks=[checkpoint,earlystop],
                          shuffle=False)
# Out:
# Epoch 1/100
# 53/54 [============================>.] - ETA: 0s - loss: 0.3721 - accuracy: 0.8759 - jaccard_coef: 0.6871 - precision: 0.8971 - recall: 0.8526 - f1: 0.8740
# Epoch 1: val_accuracy did not improve from 0.82588
# 54/54 [==============================] - 7s 120ms/step - loss: 0.3741 - accuracy: 0.8753 - jaccard_coef: 0.6821 - precision: 0.8921 - recall: 0.8480 - f1: 0.8693 - val_loss: 0.5940 - val_accuracy: 0.8074 - val_jaccard_coef: 0.5964 - val_precision: 0.8257 - val_recall: 0.7824 - val_f1: 0.8035
# Epoch 2/100
# 53/54 [============================>.] - ETA: 0s - loss: 0.3539 - accuracy: 0.8809 - jaccard_coef: 0.6947 - precision: 0.9006 - recall: 0.8597 - f1: 0.8795
# Epoch 2: val_accuracy improved from 0.82588 to 0.82692, saving model to /content/drive/MyDrive/saved_models/cusunet5.hdf5
# 54/54 [==============================] - 11s 196ms/step - loss: 0.3558 - accuracy: 0.8803 - jaccard_coef: 0.6897 - precision: 0.8957 - recall: 0.8552 - f1: 0.8748 - val_loss: 0.5434 - val_accuracy: 0.8269 - val_jaccard_coef: 0.6288 - val_precision: 0.8428 - val_recall: 0.8076 - val_f1: 0.8248
# Epoch 3/100
# 53/54 [============================>.] - ETA: 0s - loss: 0.3401 - accuracy: 0.8850 - jaccard_coef: 0.7050 - precision: 0.9027 - recall: 0.8662 - f1: 0.8839
# Epoch 3: val_accuracy did not improve from 0.82692
# 54/54 [==============================] - 6s 112ms/step - loss: 0.3420 - accuracy: 0.8844 - jaccard_coef: 0.6995 - precision: 0.8976 - recall: 0.8613 - f1: 0.8790 - val_loss: 0.5818 - val_accuracy: 0.8211 - val_jaccard_coef: 0.6232 - val_precision: 0.8385 - val_recall: 0.8010 - val_f1: 0.8193
# Epoch 4/100
# 53/54 [============================>.] - ETA: 0s - loss: 0.3350 - accuracy: 0.8873 - jaccard_coef: 0.7093 - precision: 0.9044 - recall: 0.8690 - f1: 0.8863
# Epoch 4: val_accuracy did not improve from 0.82692
# 54/54 [==============================] - 6s 113ms/step - loss: 0.3369 - accuracy: 0.8867 - jaccard_coef: 0.7042 - precision: 0.8996 - recall: 0.8645 - f1: 0.8816 - val_loss: 0.5751 - val_accuracy: 0.8209 - val_jaccard_coef: 0.6194 - val_precision: 0.8304 - val_recall: 0.7990 - val_f1: 0.8143
# Epoch 5/100
# 53/54 [============================>.] - ETA: 0s - loss: 0.3170 - accuracy: 0.8927 - jaccard_coef: 0.7206 - precision: 0.9087 - recall: 0.8760 - f1: 0.8919
# Epoch 5: val_accuracy improved from 0.82692 to 0.82800, saving model to /content/drive/MyDrive/saved_models/cusunet5.hdf5
# 54/54 [==============================] - 9s 165ms/step - loss: 0.3189 - accuracy: 0.8920 - jaccard_coef: 0.7152 - precision: 0.9036 - recall: 0.8712 - f1: 0.8870 - val_loss: 0.5713 - val_accuracy: 0.8280 - val_jaccard_coef: 0.6354 - val_precision: 0.8417 - val_recall: 0.8113 - val_f1: 0.8262
# Epoch 6/100
# 53/54 [============================>.] - ETA: 0s - loss: 0.3106 - accuracy: 0.8940 - jaccard_coef: 0.7258 - precision: 0.9096 - recall: 0.8772 - f1: 0.8930
# Epoch 6: val_accuracy did not improve from 0.82800
# 54/54 [==============================] - 6s 113ms/step - loss: 0.3125 - accuracy: 0.8934 - jaccard_coef: 0.7201 - precision: 0.9046 - recall: 0.8725 - f1: 0.8881 - val_loss: 0.5744 - val_accuracy: 0.8255 - val_jaccard_coef: 0.6326 - val_precision: 0.8372 - val_recall: 0.8081 - val_f1: 0.8224
# Epoch 7/100
# 53/54 [============================>.] - ETA: 0s - loss: 0.3007 - accuracy: 0.8973 - jaccard_coef: 0.7323 - precision: 0.9119 - recall: 0.8819 - f1: 0.8965
# Epoch 7: val_accuracy did not improve from 0.82800
# 54/54 [==============================] - 6s 110ms/step - loss: 0.3024 - accuracy: 0.8966 - jaccard_coef: 0.7268 - precision: 0.9068 - recall: 0.8771 - f1: 0.8916 - val_loss: 0.6352 - val_accuracy: 0.8010 - val_jaccard_coef: 0.6003 - val_precision: 0.8136 - val_recall: 0.7790 - val_f1: 0.7959
# Epoch 8/100
# 53/54 [============================>.] - ETA: 0s - loss: 0.2963 - accuracy: 0.8988 - jaccard_coef: 0.7360 - precision: 0.9123 - recall: 0.8847 - f1: 0.8983
# Epoch 8: val_accuracy did not improve from 0.82800
# 54/54 [==============================] - 6s 112ms/step - loss: 0.2979 - accuracy: 0.8982 - jaccard_coef: 0.7306 - precision: 0.9073 - recall: 0.8800 - f1: 0.8934 - val_loss: 0.5828 - val_accuracy: 0.8238 - val_jaccard_coef: 0.6345 - val_precision: 0.8352 - val_recall: 0.8073 - val_f1: 0.8210
# Epoch 9/100
# 53/54 [============================>.] - ETA: 0s - loss: 0.2892 - accuracy: 0.9003 - jaccard_coef: 0.7421 - precision: 0.9139 - recall: 0.8864 - f1: 0.8999
# Epoch 9: val_accuracy did not improve from 0.82800
# 54/54 [==============================] - 6s 109ms/step - loss: 0.2907 - accuracy: 0.8997 - jaccard_coef: 0.7365 - precision: 0.9091 - recall: 0.8817 - f1: 0.8951 - val_loss: 0.6326 - val_accuracy: 0.8020 - val_jaccard_coef: 0.6125 - val_precision: 0.8204 - val_recall: 0.7866 - val_f1: 0.8031
# Epoch 10/100
# 53/54 [============================>.] - ETA: 0s - loss: 0.3052 - accuracy: 0.8957 - jaccard_coef: 0.7295 - precision: 0.9108 - recall: 0.8794 - f1: 0.8947
# Epoch 10: val_accuracy did not improve from 0.82800
# 54/54 [==============================] - 6s 112ms/step - loss: 0.3070 - accuracy: 0.8951 - jaccard_coef: 0.7230 - precision: 0.9062 - recall: 0.8743 - f1: 0.8898 - val_loss: 0.7656 - val_accuracy: 0.7818 - val_jaccard_coef: 0.5766 - val_precision: 0.7988 - val_recall: 0.7605 - val_f1: 0.7792
# Epoch 11/100
# 53/54 [============================>.] - ETA: 0s - loss: 0.3297 - accuracy: 0.8884 - jaccard_coef: 0.7180 - precision: 0.9051 - recall: 0.8705 - f1: 0.8873
# Epoch 11: val_accuracy did not improve from 0.82800
# 54/54 [==============================] - 6s 110ms/step - loss: 0.3316 - accuracy: 0.8878 - jaccard_coef: 0.7129 - precision: 0.9003 - recall: 0.8660 - f1: 0.8827 - val_loss: 0.5821 - val_accuracy: 0.8222 - val_jaccard_coef: 0.6125 - val_precision: 0.8403 - val_recall: 0.8036 - val_f1: 0.8215
# Epoch 12/100
# 53/54 [============================>.] - ETA: 0s - loss: 0.3032 - accuracy: 0.8977 - jaccard_coef: 0.7280 - precision: 0.9121 - recall: 0.8825 - f1: 0.8969
# Epoch 12: val_accuracy improved from 0.82800 to 0.83660, saving model to /content/drive/MyDrive/saved_models/cusunet5.hdf5
# Restoring model weights from the end of the best epoch: 2.
# 54/54 [==============================] - 8s 145ms/step - loss: 0.3048 - accuracy: 0.8972 - jaccard_coef: 0.7230 - precision: 0.9074 - recall: 0.8781 - f1: 0.8924 - val_loss: 0.5580 - val_accuracy: 0.8366 - val_jaccard_coef: 0.6609 - val_precision: 0.8481 - val_recall: 0.8251 - val_f1: 0.8365
# Epoch 12: early stopping

# %%
from tensorflow.keras.models import load_model

# %%
saved_model = load_model('/content/drive/MyDrive/saved_models/cusunet5.hdf5', custom_objects=({ 'precision':precision, 'recall':recall,'f1':f1,'jaccard_coef': jaccard_coef}))

# %%
import random
y_test_argmax = np.argmax(y_test, axis=3)

# %%
y_pred=saved_model.predict(X_test)
y_pred_argmax=np.argmax(y_pred, axis=3)
# Out:
# 4/4 [==============================] - 8s 497ms/step

# %%
from sklearn.metrics import classification_report

# Assuming y_pred_argmax contains the predicted class indices
# Compute precision, recall, and F1 score
print(classification_report(y_test_argmax.flatten(), y_pred_argmax.flatten()))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.97      0.96   1399826
#            1       0.83      0.91      0.87   3010573
#            2       0.84      0.54      0.66    667582
#            3       0.77      0.78      0.77    619406
#            4       0.89      0.83      0.86    790499
#            5       0.00      0.00      0.00     65714
#
#     accuracy                           0.86   6553600
#    macro avg       0.71      0.67      0.69   6553600
# weighted avg       0.85      0.86      0.85   6553600

# %%
plt.figure(figsize=(12, 8))
plt.subplot(231)
plt.title('Original Image')
plt.imshow(test_img)
plt.subplot(232)
plt.title('Testing Label')
plt.imshow(ground_truth)
plt.subplot(233)
plt.title('Prediction on test image')
plt.imshow(predicted_img)
plt.show()

# %% [markdown]
# # **Attention U-net**

# %%
import tensorflow.keras.backend as K
from sklearn.metrics import precision_score, recall_score, f1_score

def precision(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

def recall(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

def f1(y_true, y_pred):
    p = precision(y_true, y_pred)
    r = recall(y_true, y_pred)
    f1_score = 2 * ((p * r) / (p + r + K.epsilon()))
    return f1_score

# %%
from tensorflow.keras import models, layers, regularizers

# %%
def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2.0 * intersection + 1.0) / (K.sum(y_true_f) + K.sum(y_pred_f) + 1.0)

# %%
def jacard_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (intersection + 1.0) / (K.sum(y_true_f) + K.sum(y_pred_f) - intersection + 1.0)

# %%
def jacard_coef_loss(y_true, y_pred):
    return -jacard_coef(y_true, y_pred)


def dice_coef_loss(y_true, y_pred):
    return -dice_coef(y_true, y_pred)

# %%
metrics = ["accuracy", jacard_coef, precision, recall, f1]

# %%
def conv_block(x, filter_size, size, dropout, batch_norm=False):

    conv = layers.Conv2D(size, (filter_size, filter_size), padding="same")(x)
    if batch_norm is True:
        conv = layers.BatchNormalization(axis=3)(conv)
    conv = layers.Activation("relu")(conv)

    conv = layers.Conv2D(size, (filter_size, filter_size), padding="same")(conv)
    if batch_norm is True:
        conv = layers.BatchNormalization(axis=3)(conv)
    conv = layers.Activation("relu")(conv)

    if dropout > 0:
        conv = layers.Dropout(dropout)(conv)

    return conv

# %%
def repeat_elem(tensor, rep):
    # lambda function to repeat Repeats the elements of a tensor along an axis
    #by a factor of rep.
    # If tensor has shape (None, 256,256,3), lambda will return a tensor of shape
    #(None, 256,256,6), if specified axis=3 and rep=2.

     return layers.Lambda(lambda x, repnum: K.repeat_elements(x, repnum, axis=3),
                          arguments={'repnum': rep})(tensor)

# %%
def gating_signal(input, out_size, batch_norm=False):
    """
    resize the down layer feature map into the same dimension as the up layer feature map
    using 1x1 conv
    :return: the gating feature map with the same dimension of the up layer feature map
    """
    x = layers.Conv2D(out_size, (1, 1), padding='same')(input)
    if batch_norm:
        x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    return x

# %%
def attention_block(x, gating, inter_shape):
    shape_x = K.int_shape(x)
    shape_g = K.int_shape(gating)

# Getting the x signal to the same shape as the gating signal
    theta_x = layers.Conv2D(inter_shape, (2, 2), strides=(2, 2), padding='same')(x)  # 16
    shape_theta_x = K.int_shape(theta_x)

# Getting the gating signal to the same number of filters as the inter_shape
    phi_g = layers.Conv2D(inter_shape, (1, 1), padding='same')(gating)
    upsample_g = layers.Conv2DTranspose(inter_shape, (3, 3),
                                 strides=(shape_theta_x[1] // shape_g[1], shape_theta_x[2] // shape_g[2]),
                                 padding='same')(phi_g)  # 16

    concat_xg = layers.add([upsample_g, theta_x])
    act_xg = layers.Activation('relu')(concat_xg)
    psi = layers.Conv2D(1, (1, 1), padding='same')(act_xg)
    sigmoid_xg = layers.Activation('sigmoid')(psi)
    shape_sigmoid = K.int_shape(sigmoid_xg)
    upsample_psi = layers.UpSampling2D(size=(shape_x[1] // shape_sigmoid[1], shape_x[2] // shape_sigmoid[2]))(sigmoid_xg)  # 32

    upsample_psi = repeat_elem(upsample_psi, shape_x[3])

    y = layers.multiply([upsample_psi, x])

    result = layers.Conv2D(shape_x[3], (1, 1), padding='same')(y)
    result_bn = layers.BatchNormalization()(result)
    return result_bn

# %%
input_shape=(image_height,image_width,image_channels)

# %%
def Attention_UNet(input_shape, NUM_CLASSES=6, dropout_rate=0.0, batch_norm=True):
    '''
    Attention UNet,

    '''
    # network structure
    FILTER_NUM = 16 # number of basic filters for the first layer
    FILTER_SIZE = 3 # size of the convolutional filter
    UP_SAMP_SIZE = 2 # size of upsampling filters

    inputs = layers.Input(input_shape, dtype=tf.float32)

    # Downsampling layers
    # DownRes 1, convolution + pooling
    conv_128 = conv_block(inputs, FILTER_SIZE, FILTER_NUM, dropout_rate, batch_norm)
    pool_64 = layers.MaxPooling2D(pool_size=(2,2))(conv_128)
    # DownRes 2
    conv_64 = conv_block(pool_64, FILTER_SIZE, 2*FILTER_NUM, dropout_rate, batch_norm)
    pool_32 = layers.MaxPooling2D(pool_size=(2,2))(conv_64)
    # DownRes 3
    conv_32 = conv_block(pool_32, FILTER_SIZE, 4*FILTER_NUM, dropout_rate, batch_norm)
    pool_16 = layers.MaxPooling2D(pool_size=(2,2))(conv_32)
    # DownRes 4
    conv_16 = conv_block(pool_16, FILTER_SIZE, 8*FILTER_NUM, dropout_rate, batch_norm)
    pool_8 = layers.MaxPooling2D(pool_size=(2,2))(conv_16)
    # DownRes 5, convolution only
    conv_8 = conv_block(pool_8, FILTER_SIZE, 16*FILTER_NUM, dropout_rate, batch_norm)

    # Upsampling layers
    # UpRes 6, attention gated concatenation + upsampling + double residual convolution
    gating_16 = gating_signal(conv_8, 8*FILTER_NUM, batch_norm)
    att_16 = attention_block(conv_16, gating_16, 8*FILTER_NUM)
    up_16 = layers.UpSampling2D(size=(UP_SAMP_SIZE, UP_SAMP_SIZE), data_format="channels_last")(conv_8)
    up_16 = layers.concatenate([up_16, att_16], axis=3)
    up_conv_16 = conv_block(up_16, FILTER_SIZE, 8*FILTER_NUM, dropout_rate, batch_norm)
    # UpRes 7
    gating_32 = gating_signal(up_conv_16, 4*FILTER_NUM, batch_norm)
    att_32 = attention_block(conv_32, gating_32, 4*FILTER_NUM)
    up_32 = layers.UpSampling2D(size=(UP_SAMP_SIZE, UP_SAMP_SIZE), data_format="channels_last")(up_conv_16)
    up_32 = layers.concatenate([up_32, att_32], axis=3)
    up_conv_32 = conv_block(up_32, FILTER_SIZE, 4*FILTER_NUM, dropout_rate, batch_norm)
    # UpRes 8
    gating_64 = gating_signal(up_conv_32, 2*FILTER_NUM, batch_norm)
    att_64 = attention_block(conv_64, gating_64, 2*FILTER_NUM)
    up_64 = layers.UpSampling2D(size=(UP_SAMP_SIZE, UP_SAMP_SIZE), data_format="channels_last")(up_conv_32)
    up_64 = layers.concatenate([up_64, att_64], axis=3)
    up_conv_64 = conv_block(up_64, FILTER_SIZE, 2*FILTER_NUM, dropout_rate, batch_norm)
    # UpRes 9
    gating_128 = gating_signal(up_conv_64, FILTER_NUM, batch_norm)
    att_128 = attention_block(conv_128, gating_128, FILTER_NUM)
    up_128 = layers.UpSampling2D(size=(UP_SAMP_SIZE, UP_SAMP_SIZE), data_format="channels_last")(up_conv_64)
    up_128 = layers.concatenate([up_128, att_128], axis=3)
    up_conv_128 = conv_block(up_128, FILTER_SIZE, FILTER_NUM, dropout_rate, batch_norm)

    # 1*1 convolutional layers
    conv_final = layers.Conv2D(NUM_CLASSES, kernel_size=(1,1))(up_conv_128)
    conv_final = layers.BatchNormalization(axis=3)(conv_final)
    conv_final = layers.Activation('softmax')(conv_final)

    # Model integration
    model = models.Model(inputs, conv_final, name="Attention_UNet")
    return model

# %%
import os
import numpy as np
from matplotlib import pyplot as plt
from tensorflow.keras.optimizers import Adam
import tensorflow as tf
from datetime import datetime
import cv2
from PIL import Image
from keras import backend, optimizers

# %%
model= Attention_UNet(input_shape, NUM_CLASSES=6, dropout_rate=0.0, batch_norm=True)

# %%
import tensorflow as tf
tf.keras.backend.clear_session()
model.compile(optimizer="adam", loss='categorical_crossentropy', metrics=metrics)
model.summary()
# Out:
# Model: "Attention_UNet"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 256, 256, 3)]        0         []
#
#  conv2d (Conv2D)             (None, 256, 256, 16)         448       ['input_1[0][0]']
#
#  batch_normalization (Batch  (None, 256, 256, 16)         64        ['conv2d[0][0]']
#  Normalization)
#
#  activation (Activation)     (None, 256, 256, 16)         0         ['batch_normalization[0][0]']
#
#  conv2d_1 (Conv2D)           (None, 256, 256, 16)         2320      ['activation[0][0]']
#
#  batch_normalization_1 (Bat  (None, 256, 256, 16)         64        ['conv2d_1[0][0]']
#  chNormalization)
#
#  activation_1 (Activation)   (None, 256, 256, 16)         0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  max_pooling2d (MaxPooling2  (None, 128, 128, 16)         0         ['activation_1[0][0]']
#  D)
#
#  conv2d_2 (Conv2D)           (None, 128, 128, 32)         4640      ['max_pooling2d[0][0]']
#
#  batch_normalization_2 (Bat  (None, 128, 128, 32)         128       ['conv2d_2[0][0]']
#  chNormalization)
#
#  activation_2 (Activation)   (None, 128, 128, 32)         0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  conv2d_3 (Conv2D)           (None, 128, 128, 32)         9248      ['activation_2[0][0]']
#
#  batch_normalization_3 (Bat  (None, 128, 128, 32)         128       ['conv2d_3[0][0]']
#  chNormalization)
#
#  activation_3 (Activation)   (None, 128, 128, 32)         0         ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  max_pooling2d_1 (MaxPoolin  (None, 64, 64, 32)           0         ['activation_3[0][0]']
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 64, 64, 64)           18496     ['max_pooling2d_1[0][0]']
#
#  batch_normalization_4 (Bat  (None, 64, 64, 64)           256       ['conv2d_4[0][0]']
#  chNormalization)
#
#  activation_4 (Activation)   (None, 64, 64, 64)           0         ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  conv2d_5 (Conv2D)           (None, 64, 64, 64)           36928     ['activation_4[0][0]']
#
#  batch_normalization_5 (Bat  (None, 64, 64, 64)           256       ['conv2d_5[0][0]']
#  chNormalization)
#
#  activation_5 (Activation)   (None, 64, 64, 64)           0         ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  max_pooling2d_2 (MaxPoolin  (None, 32, 32, 64)           0         ['activation_5[0][0]']
#  g2D)
#
#  conv2d_6 (Conv2D)           (None, 32, 32, 128)          73856     ['max_pooling2d_2[0][0]']
#
#  batch_normalization_6 (Bat  (None, 32, 32, 128)          512       ['conv2d_6[0][0]']
#  chNormalization)
#
#  activation_6 (Activation)   (None, 32, 32, 128)          0         ['batch_normalization_6[0][0]'
#                                                                     ]
#
#  conv2d_7 (Conv2D)           (None, 32, 32, 128)          147584    ['activation_6[0][0]']
#
#  batch_normalization_7 (Bat  (None, 32, 32, 128)          512       ['conv2d_7[0][0]']
#  chNormalization)
#
#  activation_7 (Activation)   (None, 32, 32, 128)          0         ['batch_normalization_7[0][0]'
#                                                                     ]
#
#  max_pooling2d_3 (MaxPoolin  (None, 16, 16, 128)          0         ['activation_7[0][0]']
#  g2D)
#
#  conv2d_8 (Conv2D)           (None, 16, 16, 256)          295168    ['max_pooling2d_3[0][0]']
#
#  batch_normalization_8 (Bat  (None, 16, 16, 256)          1024      ['conv2d_8[0][0]']
#  chNormalization)
#
#  activation_8 (Activation)   (None, 16, 16, 256)          0         ['batch_normalization_8[0][0]'
#                                                                     ]
#
#  conv2d_9 (Conv2D)           (None, 16, 16, 256)          590080    ['activation_8[0][0]']
#
#  batch_normalization_9 (Bat  (None, 16, 16, 256)          1024      ['conv2d_9[0][0]']
#  chNormalization)
#
#  activation_9 (Activation)   (None, 16, 16, 256)          0         ['batch_normalization_9[0][0]'
#                                                                     ]
#
#  conv2d_10 (Conv2D)          (None, 16, 16, 128)          32896     ['activation_9[0][0]']
#
#  batch_normalization_10 (Ba  (None, 16, 16, 128)          512       ['conv2d_10[0][0]']
#  tchNormalization)
#
#  activation_10 (Activation)  (None, 16, 16, 128)          0         ['batch_normalization_10[0][0]
#                                                                     ']
#
#  conv2d_12 (Conv2D)          (None, 16, 16, 128)          16512     ['activation_10[0][0]']
#
#  conv2d_transpose (Conv2DTr  (None, 16, 16, 128)          147584    ['conv2d_12[0][0]']
#  anspose)
#
#  conv2d_11 (Conv2D)          (None, 16, 16, 128)          65664     ['activation_7[0][0]']
#
#  add (Add)                   (None, 16, 16, 128)          0         ['conv2d_transpose[0][0]',
#                                                                      'conv2d_11[0][0]']
#
#  activation_11 (Activation)  (None, 16, 16, 128)          0         ['add[0][0]']
#
#  conv2d_13 (Conv2D)          (None, 16, 16, 1)            129       ['activation_11[0][0]']
#
#  activation_12 (Activation)  (None, 16, 16, 1)            0         ['conv2d_13[0][0]']
#
#  up_sampling2d (UpSampling2  (None, 32, 32, 1)            0         ['activation_12[0][0]']
#  D)
#
#  lambda (Lambda)             (None, 32, 32, 128)          0         ['up_sampling2d[0][0]']
#
#  multiply (Multiply)         (None, 32, 32, 128)          0         ['lambda[0][0]',
#                                                                      'activation_7[0][0]']
#
#  conv2d_14 (Conv2D)          (None, 32, 32, 128)          16512     ['multiply[0][0]']
#
#  up_sampling2d_1 (UpSamplin  (None, 32, 32, 256)          0         ['activation_9[0][0]']
#  g2D)
#
#  batch_normalization_11 (Ba  (None, 32, 32, 128)          512       ['conv2d_14[0][0]']
#  tchNormalization)
#
#  concatenate (Concatenate)   (None, 32, 32, 384)          0         ['up_sampling2d_1[0][0]',
#                                                                      'batch_normalization_11[0][0]
#                                                                     ']
#
#  conv2d_15 (Conv2D)          (None, 32, 32, 128)          442496    ['concatenate[0][0]']
#
#  batch_normalization_12 (Ba  (None, 32, 32, 128)          512       ['conv2d_15[0][0]']
#  tchNormalization)
#
#  activation_13 (Activation)  (None, 32, 32, 128)          0         ['batch_normalization_12[0][0]
#                                                                     ']
#
#  conv2d_16 (Conv2D)          (None, 32, 32, 128)          147584    ['activation_13[0][0]']
#
#  batch_normalization_13 (Ba  (None, 32, 32, 128)          512       ['conv2d_16[0][0]']
#  tchNormalization)
#
#  activation_14 (Activation)  (None, 32, 32, 128)          0         ['batch_normalization_13[0][0]
#                                                                     ']
#
#  conv2d_17 (Conv2D)          (None, 32, 32, 64)           8256      ['activation_14[0][0]']
#
#  batch_normalization_14 (Ba  (None, 32, 32, 64)           256       ['conv2d_17[0][0]']
#  tchNormalization)
#
#  activation_15 (Activation)  (None, 32, 32, 64)           0         ['batch_normalization_14[0][0]
#                                                                     ']
#
#  conv2d_19 (Conv2D)          (None, 32, 32, 64)           4160      ['activation_15[0][0]']
#
#  conv2d_transpose_1 (Conv2D  (None, 32, 32, 64)           36928     ['conv2d_19[0][0]']
#  Transpose)
#
#  conv2d_18 (Conv2D)          (None, 32, 32, 64)           16448     ['activation_5[0][0]']
#
#  add_1 (Add)                 (None, 32, 32, 64)           0         ['conv2d_transpose_1[0][0]',
#                                                                      'conv2d_18[0][0]']
#
#  activation_16 (Activation)  (None, 32, 32, 64)           0         ['add_1[0][0]']
#
#  conv2d_20 (Conv2D)          (None, 32, 32, 1)            65        ['activation_16[0][0]']
#
#  activation_17 (Activation)  (None, 32, 32, 1)            0         ['conv2d_20[0][0]']
#
#  up_sampling2d_2 (UpSamplin  (None, 64, 64, 1)            0         ['activation_17[0][0]']
#  g2D)
#
#  lambda_1 (Lambda)           (None, 64, 64, 64)           0         ['up_sampling2d_2[0][0]']
#
#  multiply_1 (Multiply)       (None, 64, 64, 64)           0         ['lambda_1[0][0]',
#                                                                      'activation_5[0][0]']
#
#  conv2d_21 (Conv2D)          (None, 64, 64, 64)           4160      ['multiply_1[0][0]']
#
#  up_sampling2d_3 (UpSamplin  (None, 64, 64, 128)          0         ['activation_14[0][0]']
#  g2D)
#
#  batch_normalization_15 (Ba  (None, 64, 64, 64)           256       ['conv2d_21[0][0]']
#  tchNormalization)
#
#  concatenate_1 (Concatenate  (None, 64, 64, 192)          0         ['up_sampling2d_3[0][0]',
#  )                                                                   'batch_normalization_15[0][0]
#                                                                     ']
#
#  conv2d_22 (Conv2D)          (None, 64, 64, 64)           110656    ['concatenate_1[0][0]']
#
#  batch_normalization_16 (Ba  (None, 64, 64, 64)           256       ['conv2d_22[0][0]']
#  tchNormalization)
#
#  activation_18 (Activation)  (None, 64, 64, 64)           0         ['batch_normalization_16[0][0]
#                                                                     ']
#
#  conv2d_23 (Conv2D)          (None, 64, 64, 64)           36928     ['activation_18[0][0]']
#
#  batch_normalization_17 (Ba  (None, 64, 64, 64)           256       ['conv2d_23[0][0]']
#  tchNormalization)
#
#  activation_19 (Activation)  (None, 64, 64, 64)           0         ['batch_normalization_17[0][0]
#                                                                     ']
#
#  conv2d_24 (Conv2D)          (None, 64, 64, 32)           2080      ['activation_19[0][0]']
#
#  batch_normalization_18 (Ba  (None, 64, 64, 32)           128       ['conv2d_24[0][0]']
#  tchNormalization)
#
#  activation_20 (Activation)  (None, 64, 64, 32)           0         ['batch_normalization_18[0][0]
#                                                                     ']
#
#  conv2d_26 (Conv2D)          (None, 64, 64, 32)           1056      ['activation_20[0][0]']
#
#  conv2d_transpose_2 (Conv2D  (None, 64, 64, 32)           9248      ['conv2d_26[0][0]']
#  Transpose)
#
#  conv2d_25 (Conv2D)          (None, 64, 64, 32)           4128      ['activation_3[0][0]']
#
#  add_2 (Add)                 (None, 64, 64, 32)           0         ['conv2d_transpose_2[0][0]',
#                                                                      'conv2d_25[0][0]']
#
#  activation_21 (Activation)  (None, 64, 64, 32)           0         ['add_2[0][0]']
#
#  conv2d_27 (Conv2D)          (None, 64, 64, 1)            33        ['activation_21[0][0]']
#
#  activation_22 (Activation)  (None, 64, 64, 1)            0         ['conv2d_27[0][0]']
#
#  up_sampling2d_4 (UpSamplin  (None, 128, 128, 1)          0         ['activation_22[0][0]']
#  g2D)
#
#  lambda_2 (Lambda)           (None, 128, 128, 32)         0         ['up_sampling2d_4[0][0]']
#
#  multiply_2 (Multiply)       (None, 128, 128, 32)         0         ['lambda_2[0][0]',
#                                                                      'activation_3[0][0]']
#
#  conv2d_28 (Conv2D)          (None, 128, 128, 32)         1056      ['multiply_2[0][0]']
#
#  up_sampling2d_5 (UpSamplin  (None, 128, 128, 64)         0         ['activation_19[0][0]']
#  g2D)
#
#  batch_normalization_19 (Ba  (None, 128, 128, 32)         128       ['conv2d_28[0][0]']
#  tchNormalization)
#
#  concatenate_2 (Concatenate  (None, 128, 128, 96)         0         ['up_sampling2d_5[0][0]',
#  )                                                                   'batch_normalization_19[0][0]
#                                                                     ']
#
#  conv2d_29 (Conv2D)          (None, 128, 128, 32)         27680     ['concatenate_2[0][0]']
#
#  batch_normalization_20 (Ba  (None, 128, 128, 32)         128       ['conv2d_29[0][0]']
#  tchNormalization)
#
#  activation_23 (Activation)  (None, 128, 128, 32)         0         ['batch_normalization_20[0][0]
#                                                                     ']
#
#  conv2d_30 (Conv2D)          (None, 128, 128, 32)         9248      ['activation_23[0][0]']
#
#  batch_normalization_21 (Ba  (None, 128, 128, 32)         128       ['conv2d_30[0][0]']
#  tchNormalization)
#
#  activation_24 (Activation)  (None, 128, 128, 32)         0         ['batch_normalization_21[0][0]
#                                                                     ']
#
#  conv2d_31 (Conv2D)          (None, 128, 128, 16)         528       ['activation_24[0][0]']
#
#  batch_normalization_22 (Ba  (None, 128, 128, 16)         64        ['conv2d_31[0][0]']
#  tchNormalization)
#
#  activation_25 (Activation)  (None, 128, 128, 16)         0         ['batch_normalization_22[0][0]
#                                                                     ']
#
#  conv2d_33 (Conv2D)          (None, 128, 128, 16)         272       ['activation_25[0][0]']
#
#  conv2d_transpose_3 (Conv2D  (None, 128, 128, 16)         2320      ['conv2d_33[0][0]']
#  Transpose)
#
#  conv2d_32 (Conv2D)          (None, 128, 128, 16)         1040      ['activation_1[0][0]']
#
#  add_3 (Add)                 (None, 128, 128, 16)         0         ['conv2d_transpose_3[0][0]',
#                                                                      'conv2d_32[0][0]']
#
#  activation_26 (Activation)  (None, 128, 128, 16)         0         ['add_3[0][0]']
#
#  conv2d_34 (Conv2D)          (None, 128, 128, 1)          17        ['activation_26[0][0]']
#
#  activation_27 (Activation)  (None, 128, 128, 1)          0         ['conv2d_34[0][0]']
#
#  up_sampling2d_6 (UpSamplin  (None, 256, 256, 1)          0         ['activation_27[0][0]']
#  g2D)
#
#  lambda_3 (Lambda)           (None, 256, 256, 16)         0         ['up_sampling2d_6[0][0]']
#
#  multiply_3 (Multiply)       (None, 256, 256, 16)         0         ['lambda_3[0][0]',
#                                                                      'activation_1[0][0]']
#
#  conv2d_35 (Conv2D)          (None, 256, 256, 16)         272       ['multiply_3[0][0]']
#
#  up_sampling2d_7 (UpSamplin  (None, 256, 256, 32)         0         ['activation_24[0][0]']
#  g2D)
#
#  batch_normalization_23 (Ba  (None, 256, 256, 16)         64        ['conv2d_35[0][0]']
#  tchNormalization)
#
#  concatenate_3 (Concatenate  (None, 256, 256, 48)         0         ['up_sampling2d_7[0][0]',
#  )                                                                   'batch_normalization_23[0][0]
#                                                                     ']
#
#  conv2d_36 (Conv2D)          (None, 256, 256, 16)         6928      ['concatenate_3[0][0]']
#
#  batch_normalization_24 (Ba  (None, 256, 256, 16)         64        ['conv2d_36[0][0]']
#  tchNormalization)
#
#  activation_28 (Activation)  (None, 256, 256, 16)         0         ['batch_normalization_24[0][0]
#                                                                     ']
#
#  conv2d_37 (Conv2D)          (None, 256, 256, 16)         2320      ['activation_28[0][0]']
#
#  batch_normalization_25 (Ba  (None, 256, 256, 16)         64        ['conv2d_37[0][0]']
#  tchNormalization)
#
#  activation_29 (Activation)  (None, 256, 256, 16)         0         ['batch_normalization_25[0][0]
#                                                                     ']
#
#  conv2d_38 (Conv2D)          (None, 256, 256, 6)          102       ['activation_29[0][0]']
#
#  batch_normalization_26 (Ba  (None, 256, 256, 6)          24        ['conv2d_38[0][0]']
#  tchNormalization)
#
#  activation_30 (Activation)  (None, 256, 256, 6)          0         ['batch_normalization_26[0][0]
#                                                                     ']
#
# ==================================================================================================
# Total params: 2341906 (8.93 MB)
# Trainable params: 2337990 (8.92 MB)
# Non-trainable params: 3916 (15.30 KB)
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.callbacks import ModelCheckpoint,EarlyStopping,ReduceLROnPlateau
model_filepath = "/content/drive/MyDrive/saved_models/attenunet3.hdf5"
checkpoint = ModelCheckpoint(
    filepath=model_filepath,
    monitor='val_accuracy',
    mode='max',
    save_best_only=True,
    verbose=1
)
earlystop = EarlyStopping(
    monitor = 'val_loss',c
    min_delta = 0.001,
    patience = 15,
    mode = 'auto',
    verbose = 1,
    restore_best_weights = True
)
redr = ReduceLROnPlateau(factor=0.5, patience=10, min_lr=1e-6)

# %%
model_history = model.fit(X_train, y_train,
                          batch_size=8,  # Adjust batch size
                          verbose=1,
                          epochs=100,
                          validation_data=(X_test, y_test),
                          callbacks=[checkpoint],
                          shuffle=False)
# Out:
# Epoch 1/100
# 40/40 [==============================] - ETA: 0s - loss: 1.2875 - accuracy: 0.6012 - jacard_coef: 0.2118 - precision: 0.8178 - recall: 0.2849 - f1: 0.4137
# Epoch 1: val_accuracy improved from -inf to 0.58729, saving model to /content/drive/MyDrive/saved_models/attenunet3.hdf5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 40/40 [==============================] - 44s 285ms/step - loss: 1.2875 - accuracy: 0.6012 - jacard_coef: 0.2118 - precision: 0.8178 - recall: 0.2849 - f1: 0.4137 - val_loss: 1.5137 - val_accuracy: 0.5873 - val_jacard_coef: 0.1413 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1: 0.0000e+00
# Epoch 2/100
# 40/40 [==============================] - ETA: 0s - loss: 1.1254 - accuracy: 0.6750 - jacard_coef: 0.2498 - precision: 0.8795 - recall: 0.3950 - f1: 0.5408
# Epoch 2: val_accuracy did not improve from 0.58729
# 40/40 [==============================] - 6s 139ms/step - loss: 1.1254 - accuracy: 0.6750 - jacard_coef: 0.2498 - precision: 0.8795 - recall: 0.3950 - f1: 0.5408 - val_loss: 1.6422 - val_accuracy: 0.2602 - val_jacard_coef: 0.1157 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1: 0.0000e+00
# Epoch 3/100
# 40/40 [==============================] - ETA: 0s - loss: 1.0464 - accuracy: 0.7148 - jacard_coef: 0.2775 - precision: 0.8807 - recall: 0.4842 - f1: 0.6209
# Epoch 3: val_accuracy did not improve from 0.58729
# 40/40 [==============================] - 6s 139ms/step - loss: 1.0464 - accuracy: 0.7148 - jacard_coef: 0.2775 - precision: 0.8807 - recall: 0.4842 - f1: 0.6209 - val_loss: 1.6707 - val_accuracy: 0.2604 - val_jacard_coef: 0.1266 - val_precision: 0.1000 - val_recall: 0.0042 - val_f1: 0.0080
# Epoch 4/100
# 40/40 [==============================] - ETA: 0s - loss: 0.9948 - accuracy: 0.7333 - jacard_coef: 0.2970 - precision: 0.8709 - recall: 0.5319 - f1: 0.6576
# Epoch 4: val_accuracy did not improve from 0.58729
# 40/40 [==============================] - 5s 132ms/step - loss: 0.9948 - accuracy: 0.7333 - jacard_coef: 0.2970 - precision: 0.8709 - recall: 0.5319 - f1: 0.6576 - val_loss: 1.6291 - val_accuracy: 0.2885 - val_jacard_coef: 0.1366 - val_precision: 0.9044 - val_recall: 0.1432 - val_f1: 0.2392
# Epoch 5/100
# 40/40 [==============================] - ETA: 0s - loss: 0.9450 - accuracy: 0.7459 - jacard_coef: 0.3155 - precision: 0.8759 - recall: 0.5692 - f1: 0.6879
# Epoch 5: val_accuracy did not improve from 0.58729
# 40/40 [==============================] - 6s 141ms/step - loss: 0.9450 - accuracy: 0.7459 - jacard_coef: 0.3155 - precision: 0.8759 - recall: 0.5692 - f1: 0.6879 - val_loss: 1.3893 - val_accuracy: 0.5714 - val_jacard_coef: 0.1893 - val_precision: 0.6625 - val_recall: 0.2310 - val_f1: 0.3396
# Epoch 6/100
# 40/40 [==============================] - ETA: 0s - loss: 0.9051 - accuracy: 0.7586 - jacard_coef: 0.3307 - precision: 0.8765 - recall: 0.5899 - f1: 0.7036
# Epoch 6: val_accuracy improved from 0.58729 to 0.60035, saving model to /content/drive/MyDrive/saved_models/attenunet3.hdf5
# 40/40 [==============================] - 7s 181ms/step - loss: 0.9051 - accuracy: 0.7586 - jacard_coef: 0.3307 - precision: 0.8765 - recall: 0.5899 - f1: 0.7036 - val_loss: 1.3300 - val_accuracy: 0.6003 - val_jacard_coef: 0.1896 - val_precision: 0.9399 - val_recall: 0.1515 - val_f1: 0.2529
# Epoch 7/100
# 40/40 [==============================] - ETA: 0s - loss: 0.8813 - accuracy: 0.7615 - jacard_coef: 0.3426 - precision: 0.8736 - recall: 0.6114 - f1: 0.7181
# Epoch 7: val_accuracy improved from 0.60035 to 0.65242, saving model to /content/drive/MyDrive/saved_models/attenunet3.hdf5
# 40/40 [==============================] -
[==============================] - ETA: 0s - loss: 0.1385 - accuracy: 0.9557 - jacard_coef: 0.8443 - precision: 0.9600 - recall: 0.9514 - f1: 0.9557
# Epoch 100: val_accuracy did not improve from 0.84315
# 40/40 [==============================] - 6s 148ms/step - loss: 0.1385 - accuracy: 0.9557 - jacard_coef: 0.8443 - precision: 0.9600 - recall: 0.9514 - f1: 0.9557 - val_loss: 0.5748 - val_accuracy: 0.8354 - val_jacard_coef: 0.6678 - val_precision: 0.8445 - val_recall: 0.8272 - val_f1: 0.8357

# %%
history_a = model_history

# %%
loss = history_a.history['loss']
val_loss = history_a.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label="Training Loss")
plt.plot(epochs, val_loss, 'r', label="Validation Loss")
plt.title("Training Vs Validation Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %%
jacard_coef = history_a.history['jacard_coef']
val_jacard_coef = history_a.history['val_jacard_coef']

epochs = range(1, len(jacard_coef) + 1)
plt.plot(epochs, jacard_coef, 'y', label="Training IoU")
plt.plot(epochs, val_jacard_coef, 'r', label="Validation IoU")
plt.title("Training Vs Validation IoU")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %%
import random
y_test_argmax = np.argmax(y_test, axis=3)

# %%
test_image_number = random.randint(0, len(X_test))

test_image = X_test[test_image_number]
ground_truth_image = y_test_argmax[test_image_number]

test_image_input = np.expand_dims(test_image, 0)

prediction = new_model.predict(test_image_input)
predicted_image = np.argmax(prediction, axis=3)
predicted_image = predicted_image[0,:,:]
# Out:
# 1/1 [==============================] - 2s 2s/step

# %%
plt.figure(figsize=(14,8))
plt.subplot(231)
plt.title("Original Image")
plt.imshow(test_image)
plt.subplot(232)
plt.title("Original Masked image")
plt.imshow(ground_truth_image)
plt.subplot(233)
plt.title("Predicted Image")
plt.imshow(predicted_image)

# %%
from keras.models import load_model
new_model = load_model('/content/drive/MyDrive/saved_models/attenunet3.hdf5', custom_objects=({'precision':precision, 'recall':recall,'f1':f1,
                                          'jacard_coef': jacard_coef}))

# %%
y_pred=new_model.predict(X_test)
y_pred_argmax=np.argmax(y_pred, axis=3)
# Out:
# 4/4 [==============================] - 0s 144ms/step

# %%
from sklearn.metrics import classification_report

# Assuming y_pred_argmax contains the predicted class indices
# Compute precision, recall, and F1 score
print(classification_report(y_test_argmax.flatten(), y_pred_argmax.flatten()))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.97      0.94   1399826
#            1       0.85      0.91      0.88   3010573
#            2       0.88      0.55      0.67    667582
#            3       0.76      0.83      0.79    619406
#            4       0.92      0.86      0.89    790499
#            5       0.18      0.01      0.02     65714
#
#     accuracy                           0.86   6553600
#    macro avg       0.75      0.69      0.70   6553600
# weighted avg       0.86      0.86      0.86   6553600

# %% [markdown]
# # **Attention_ResUNet**

# %%
import tensorflow.keras.backend as K
from sklearn.metrics import precision_score, recall_score, f1_score

def precision(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

def recall(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

def f1(y_true, y_pred):
    p = precision(y_true, y_pred)
    r = recall(y_true, y_pred)
    f1_score = 2 * ((p * r) / (p + r + K.epsilon()))
    return f1_score

# %%
from tensorflow.keras import models, layers, regularizers

# %%
def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2.0 * intersection + 1.0) / (K.sum(y_true_f) + K.sum(y_pred_f) + 1.0)

# %%
def jacard_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (intersection + 1.0) / (K.sum(y_true_f) + K.sum(y_pred_f) - intersection + 1.0)

# %%
def jacard_coef_loss(y_true, y_pred):
    return -jacard_coef(y_true, y_pred)


def dice_coef_loss(y_true, y_pred):
    return -dice_coef(y_true, y_pred)

# %%
metrics = ["accuracy", jacard_coef, precision, recall, f1]

# %%
def conv_block(x, filter_size, size, dropout, batch_norm=False):

    conv = layers.Conv2D(size, (filter_size, filter_size), padding="same")(x)
    if batch_norm is True:
        conv = layers.BatchNormalization(axis=3)(conv)
    conv = layers.Activation("relu")(conv)

    conv = layers.Conv2D(size, (filter_size, filter_size), padding="same")(conv)
    if batch_norm is True:
        conv = layers.BatchNormalization(axis=3)(conv)
    conv = layers.Activation("relu")(conv)

    if dropout > 0:
        conv = layers.Dropout(dropout)(conv)

    return conv

# %%
def repeat_elem(tensor, rep):
    # lambda function to repeat Repeats the elements of a tensor along an axis
    #by a factor of rep.
    # If tensor has shape (None, 256,256,3), lambda will return a tensor of shape
    #(None, 256,256,6), if specified axis=3 and rep=2.

     return layers.Lambda(lambda x, repnum: K.repeat_elements(x, repnum, axis=3),
                          arguments={'repnum': rep})(tensor)

# %%
def gating_signal(input, out_size, batch_norm=False):
    """
    resize the down layer feature map into the same dimension as the up layer feature map
    using 1x1 conv
    :return: the gating feature map with the same dimension of the up layer feature map
    """
    x = layers.Conv2D(out_size, (1, 1), padding='same')(input)
    if batch_norm:
        x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    return x

# %%
def attention_block(x, gating, inter_shape):
    shape_x = K.int_shape(x)
    shape_g = K.int_shape(gating)

# Getting the x signal to the same shape as the gating signal
    theta_x = layers.Conv2D(inter_shape, (2, 2), strides=(2, 2), padding='same')(x)  # 16
    shape_theta_x = K.int_shape(theta_x)

# Getting the gating signal to the same number of filters as the inter_shape
    phi_g = layers.Conv2D(inter_shape, (1, 1), padding='same')(gating)
    upsample_g = layers.Conv2DTranspose(inter_shape, (3, 3),
                                 strides=(shape_theta_x[1] // shape_g[1], shape_theta_x[2] // shape_g[2]),
                                 padding='same')(phi_g)  # 16

    concat_xg = layers.add([upsample_g, theta_x])
    act_xg = layers.Activation('relu')(concat_xg)
    psi = layers.Conv2D(1, (1, 1), padding='same')(act_xg)
    sigmoid_xg = layers.Activation('sigmoid')(psi)
    shape_sigmoid = K.int_shape(sigmoid_xg)
    upsample_psi = layers.UpSampling2D(size=(shape_x[1] // shape_sigmoid[1], shape_x[2] // shape_sigmoid[2]))(sigmoid_xg)  # 32

    upsample_psi = repeat_elem(upsample_psi, shape_x[3])

    y = layers.multiply([upsample_psi, x])

    result = layers.Conv2D(shape_x[3], (1, 1), padding='same')(y)
    result_bn = layers.BatchNormalization()(result)
    return result_bn

# %%
def res_conv_block(x, filter_size, size, dropout, batch_norm=False):
    '''
    Residual convolutional layer.
    Two variants....
    Either put activation function before the addition with shortcut
    or after the addition (which would be as proposed in the original resNet).

    1. conv - BN - Activation - conv - BN - Activation
                                          - shortcut  - BN - shortcut+BN

    2. conv - BN - Activation - conv - BN
                                     - shortcut  - BN - shortcut+BN - Activation

    Check fig 4 in https://arxiv.org/ftp/arxiv/papers/1802/1802.06955.pdf
    '''

    conv = layers.Conv2D(size, (filter_size, filter_size), padding='same')(x)
    if batch_norm is True:
        conv = layers.BatchNormalization(axis=3)(conv)
    conv = layers.Activation('relu')(conv)

    conv = layers.Conv2D(size, (filter_size, filter_size), padding='same')(conv)
    if batch_norm is True:
        conv = layers.BatchNormalization(axis=3)(conv)
    #conv = layers.Activation('relu')(conv)    #Activation before addition with shortcut
    if dropout > 0:
        conv = layers.Dropout(dropout)(conv)

    shortcut = layers.Conv2D(size, kernel_size=(1, 1), padding='same')(x)
    if batch_norm is True:
        shortcut = layers.BatchNormalization(axis=3)(shortcut)

    res_path = layers.add([shortcut, conv])
    res_path = layers.Activation('relu')(res_path)    #Activation after addition with shortcut (Original residual block)
    return res_path

# %%
input_shape=(image_height,image_width,image_channels)

# %%
def Attention_ResUNet(input_shape, NUM_CLASSES=6, dropout_rate=0.2, batch_norm=True):
    '''
    Rsidual UNet, with attention

    '''
    # network structure
    FILTER_NUM = 16 # number of basic filters for the first layer
    FILTER_SIZE = 3 # size of the convolutional filter
    UP_SAMP_SIZE = 2 # size of upsampling filters
    # input data
    # dimension of the image depth
    inputs = layers.Input(input_shape, dtype=tf.float32)
    axis = 3

    # Downsampling layers
    # DownRes 1, double residual convolution + pooling
    conv_128 = res_conv_block(inputs, FILTER_SIZE, FILTER_NUM, dropout_rate, batch_norm)
    pool_64 = layers.MaxPooling2D(pool_size=(2,2))(conv_128)
    # DownRes 2
    conv_64 = res_conv_block(pool_64, FILTER_SIZE, 2*FILTER_NUM, dropout_rate, batch_norm)
    pool_32 = layers.MaxPooling2D(pool_size=(2,2))(conv_64)
    # DownRes 3
    conv_32 = res_conv_block(pool_32, FILTER_SIZE, 4*FILTER_NUM, dropout_rate, batch_norm)
    pool_16 = layers.MaxPooling2D(pool_size=(2,2))(conv_32)
    # DownRes 4
    conv_16 = res_conv_block(pool_16, FILTER_SIZE, 8*FILTER_NUM, dropout_rate, batch_norm)
    pool_8 = layers.MaxPooling2D(pool_size=(2,2))(conv_16)
    # DownRes 5, convolution only
    conv_8 = res_conv_block(pool_8, FILTER_SIZE, 16*FILTER_NUM, dropout_rate, batch_norm)

    # Upsampling layers
    # UpRes 6, attention gated concatenation + upsampling + double residual convolution
    gating_16 = gating_signal(conv_8, 8*FILTER_NUM, batch_norm)
    att_16 = attention_block(conv_16, gating_16, 8*FILTER_NUM)
    up_16 = layers.UpSampling2D(size=(UP_SAMP_SIZE, UP_SAMP_SIZE), data_format="channels_last")(conv_8)
    up_16 = layers.concatenate([up_16, att_16], axis=axis)
    up_conv_16 = res_conv_block(up_16, FILTER_SIZE, 8*FILTER_NUM, dropout_rate, batch_norm)
    # UpRes 7
    gating_32 = gating_signal(up_conv_16, 4*FILTER_NUM, batch_norm)
    att_32 = attention_block(conv_32, gating_32, 4*FILTER_NUM)
    up_32 = layers.UpSampling2D(size=(UP_SAMP_SIZE, UP_SAMP_SIZE), data_format="channels_last")(up_conv_16)
    up_32 = layers.concatenate([up_32, att_32], axis=axis)
    up_conv_32 = res_conv_block(up_32, FILTER_SIZE, 4*FILTER_NUM, dropout_rate, batch_norm)
    # UpRes 8
    gating_64 = gating_signal(up_conv_32, 2*FILTER_NUM, batch_norm)
    att_64 = attention_block(conv_64, gating_64, 2*FILTER_NUM)
    up_64 = layers.UpSampling2D(size=(UP_SAMP_SIZE, UP_SAMP_SIZE), data_format="channels_last")(up_conv_32)
    up_64 = layers.concatenate([up_64, att_64], axis=axis)
    up_conv_64 = res_conv_block(up_64, FILTER_SIZE, 2*FILTER_NUM, dropout_rate, batch_norm)
    # UpRes 9
    gating_128 = gating_signal(up_conv_64, FILTER_NUM, batch_norm)
    att_128 = attention_block(conv_128, gating_128, FILTER_NUM)
    up_128 = layers.UpSampling2D(size=(UP_SAMP_SIZE, UP_SAMP_SIZE), data_format="channels_last")(up_conv_64)
    up_128 = layers.concatenate([up_128, att_128], axis=axis)
    up_conv_128 = res_conv_block(up_128, FILTER_SIZE, FILTER_NUM, dropout_rate, batch_norm)

    # 1*1 convolutional layers

    conv_final = layers.Conv2D(NUM_CLASSES, kernel_size=(1,1))(up_conv_128)
    conv_final = layers.BatchNormalization(axis=axis)(conv_final)
    conv_final = layers.Activation('softmax')(conv_final)  #Change to softmax for multichannel

    # Model integration
    model = models.Model(inputs, conv_final, name="AttentionResUNet")
    return model

# %%
import os
import numpy as np
from matplotlib import pyplot as plt
from tensorflow.keras.optimizers import Adam
import tensorflow as tf
from datetime import datetime
import cv2
from PIL import Image
from keras import backend, optimizers

# %%
model= Attention_ResUNet(input_shape, NUM_CLASSES=6, dropout_rate=0.2, batch_norm=True)

# %%
import tensorflow as tf
tf.keras.backend.clear_session()
model.compile(optimizer="adam", loss='categorical_crossentropy', metrics=metrics)
model.summary()
# Out:
# Model: "AttentionResUNet"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 256, 256, 3)]        0         []
#
#  conv2d (Conv2D)             (None, 256, 256, 16)         448       ['input_1[0][0]']
#
#  batch_normalization (Batch  (None, 256, 256, 16)         64        ['conv2d[0][0]']
#  Normalization)
#
#  activation (Activation)     (None, 256, 256, 16)         0         ['batch_normalization[0][0]']
#
#  conv2d_1 (Conv2D)           (None, 256, 256, 16)         2320      ['activation[0][0]']
#
#  conv2d_2 (Conv2D)           (None, 256, 256, 16)         64        ['input_1[0][0]']
#
#  batch_normalization_1 (Bat  (None, 256, 256, 16)         64        ['conv2d_1[0][0]']
#  chNormalization)
#
#  batch_normalization_2 (Bat  (None, 256, 256, 16)         64        ['conv2d_2[0][0]']
#  chNormalization)
#
#  dropout (Dropout)           (None, 256, 256, 16)         0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  add (Add)                   (None, 256, 256, 16)         0         ['batch_normalization_2[0][0]'
#                                                                     , 'dropout[0][0]']
#
#  activation_1 (Activation)   (None, 256, 256, 16)         0         ['add[0][0]']
#
#  max_pooling2d (MaxPooling2  (None, 128, 128, 16)         0         ['activation_1[0][0]']
#  D)
#
#  conv2d_3 (Conv2D)           (None, 128, 128, 32)         4640      ['max_pooling2d[0][0]']
#
#  batch_normalization_3 (Bat  (None, 128, 128, 32)         128       ['conv2d_3[0][0]']
#  chNormalization)
#
#  activation_2 (Activation)   (None, 128, 128, 32)         0         ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  conv2d_4 (Conv2D)           (None, 128, 128, 32)         9248      ['activation_2[0][0]']
#
#  conv2d_5 (Conv2D)           (None, 128, 128, 32)         544       ['max_pooling2d[0][0]']
#
#  batch_normalization_4 (Bat  (None, 128, 128, 32)         128       ['conv2d_4[0][0]']
#  chNormalization)
#
#  batch_normalization_5 (Bat  (None, 128, 128, 32)         128       ['conv2d_5[0][0]']
#  chNormalization)
#
#  dropout_1 (Dropout)         (None, 128, 128, 32)         0         ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  add_1 (Add)                 (None, 128, 128, 32)         0         ['batch_normalization_5[0][0]'
#                                                                     , 'dropout_1[0][0]']
#
#  activation_3 (Activation)   (None, 128, 128, 32)         0         ['add_1[0][0]']
#
#  max_pooling2d_1 (MaxPoolin  (None, 64, 64, 32)           0         ['activation_3[0][0]']
#  g2D)
#
#  conv2d_6 (Conv2D)           (None, 64, 64, 64)           18496     ['max_pooling2d_1[0][0]']
#
#  batch_normalization_6 (Bat  (None, 64, 64, 64)           256       ['conv2d_6[0][0]']
#  chNormalization)
#
#  activation_4 (Activation)   (None, 64, 64, 64)           0         ['batch_normalization_6[0][0]'
#                                                                     ]
#
#  conv2d_7 (Conv2D)           (None, 64, 64, 64)           36928     ['activation_4[0][0]']
#
#  conv2d_8 (Conv2D)           (None, 64, 64, 64)           2112      ['max_pooling2d_1[0][0]']
#
#  batch_normalization_7 (Bat  (None, 64, 64, 64)           256       ['conv2d_7[0][0]']
#  chNormalization)
#
#  batch_normalization_8 (Bat  (None, 64, 64, 64)           256       ['conv2d_8[0][0]']
#  chNormalization)
#
#  dropout_2 (Dropout)         (None, 64, 64, 64)           0         ['batch_normalization_7[0][0]'
#                                                                     ]
#
#  add_2 (Add)                 (None, 64, 64, 64)           0         ['batch_normalization_8[0][0]'
#                                                                     , 'dropout_2[0][0]']
#
#  activation_5 (Activation)   (None, 64, 64, 64)           0         ['add_2[0][0]']
#
#  max_pooling2d_2 (MaxPoolin  (None, 32, 32, 64)           0         ['activation_5[0][0]']
#  g2D)
#
#  conv2d_9 (Conv2D)           (None, 32, 32, 128)          73856     ['max_pooling2d_2[0][0]']
#
#  batch_normalization_9 (Bat  (None, 32, 32, 128)          512       ['conv2d_9[0][0]']
#  chNormalization)
#
#  activation_6 (Activation)   (None, 32, 32, 128)          0         ['batch_normalization_9[0][0]'
#                                                                     ]
#
#  conv2d_10 (Conv2D)          (None, 32, 32, 128)          147584    ['activation_6[0][0]']
#
#  conv2d_11 (Conv2D)          (None, 32, 32, 128)          8320      ['max_pooling2d_2[0][0]']
#
#  batch_normalization_10 (Ba  (None, 32, 32, 128)          512       ['conv2d_10[0][0]']
#  tchNormalization)
#
#  batch_normalization_11 (Ba  (None, 32, 32, 128)          512       ['conv2d_11[0][0]']
#  tchNormalization)
#
#  dropout_3 (Dropout)         (None, 32, 32, 128)          0         ['batch_normalization_10[0][0]
#                                                                     ']
#
#  add_3 (Add)                 (None, 32, 32, 128)          0         ['batch_normalization_11[0][0]
#                                                                     ',
#                                                                      'dropout_3[0][0]']
#
#  activation_7 (Activation)   (None, 32, 32, 128)          0         ['add_3[0][0]']
#
#  max_pooling2d_3 (MaxPoolin  (None, 16, 16, 128)          0         ['activation_7[0][0]']
#  g2D)
#
#  conv2d_12 (Conv2D)          (None, 16, 16, 256)          295168    ['max_pooling2d_3[0][0]']
#
#  batch_normalization_12 (Ba  (None, 16, 16, 256)          1024      ['conv2d_12[0][0]']
#  tchNormalization)
#
#  activation_8 (Activation)   (None, 16, 16, 256)          0         ['batch_normalization_12[0][0]
#                                                                     ']
#
#  conv2d_13 (Conv2D)          (None, 16, 16, 256)          590080    ['activation_8[0][0]']
#
#  conv2d_14 (Conv2D)          (None, 16, 16, 256)          33024     ['max_pooling2d_3[0][0]']
#
#  batch_normalization_13 (Ba  (None, 16, 16, 256)          1024      ['conv2d_13[0][0]']
#  tchNormalization)
#
#  batch_normalization_14 (Ba  (None, 16, 16, 256)          1024      ['conv2d_14[0][0]']
#  tchNormalization)
#
#  dropout_4 (Dropout)         (None, 16, 16, 256)          0         ['batch_normalization_13[0][0]
#                                                                     ']
#
#  add_4 (Add)                 (None, 16, 16, 256)          0         ['batch_normalization_14[0][0]
#                                                                     ',
#                                                                      'dropout_4[0][0]']
#
#  activation_9 (Activation)   (None, 16, 16, 256)          0         ['add_4[0][0]']
#
#  conv2d_15 (Conv2D)          (None, 16, 16, 128)          32896     ['activation_9[0][0]']
#
#  batch_normalization_15 (Ba  (None, 16, 16, 128)          512       ['conv2d_15[0][0]']
#  tchNormalization)
#
#  activation_10 (Activation)  (None, 16, 16, 128)          0         ['batch_normalization_15[0][0]
#                                                                     ']
#
#  conv2d_17 (Conv2D)          (None, 16, 16, 128)          16512     ['activation_10[0][0]']
#
#  conv2d_transpose (Conv2DTr  (None, 16, 16, 128)          147584    ['conv2d_17[0][0]']
#  anspose)
#
#  conv2d_16 (Conv2D)          (None, 16, 16, 128)          65664     ['activation_7[0][0]']
#
#  add_5 (Add)                 (None, 16, 16, 128)          0         ['conv2d_transpose[0][0]',
#                                                                      'conv2d_16[0][0]']
#
#  activation_11 (Activation)  (None, 16, 16, 128)          0         ['add_5[0][0]']
#
#  conv2d_18 (Conv2D)          (None, 16, 16, 1)            129       ['activation_11[0][0]']
#
#  activation_12 (Activation)  (None, 16, 16, 1)            0         ['conv2d_18[0][0]']
#
#  up_sampling2d (UpSampling2  (None, 32, 32, 1)            0         ['activation_12[0][0]']
#  D)
#
#  lambda (Lambda)             (None, 32, 32, 128)          0         ['up_sampling2d[0][0]']
#
#  multiply (Multiply)         (None, 32, 32, 128)          0         ['lambda[0][0]',
#                                                                      'activation_7[0][0]']
#
#  conv2d_19 (Conv2D)          (None, 32, 32, 128)          16512     ['multiply[0][0]']
#
#  up_sampling2d_1 (UpSamplin  (None, 32, 32, 256)          0         ['activation_9[0][0]']
#  g2D)
#
#  batch_normalization_16 (Ba  (None, 32, 32, 128)          512       ['conv2d_19[0][0]']
#  tchNormalization)
#
#  concatenate (Concatenate)   (None, 32, 32, 384)          0         ['up_sampling2d_1[0][0]',
#                                                                      'batch_normalization_16[0][0]
#                                                                     ']
#
#  conv2d_20 (Conv2D)          (None, 32, 32, 128)          442496    ['concatenate[0][0]']
#
#  batch_normalization_17 (Ba  (None, 32, 32, 128)          512       ['conv2d_20[0][0]']
#  tchNormalization)
#
#  activation_13 (Activation)  (None, 32, 32, 128)          0         ['batch_normalization_17[0][0]
#                                                                     ']
#
#  conv2d_21 (Conv2D)          (None, 32, 32, 128)          147584    ['activation_13[0][0]']
#
#  conv2d_22 (Conv2D)          (None, 32, 32, 128)          49280     ['concatenate[0][0]']
#
#  batch_normalization_18 (Ba  (None, 32, 32, 128)          512       ['conv2d_21[0][0]']
#  tchNormalization)
#
#  batch_normalization_19 (Ba  (None, 32, 32, 128)          512       ['conv2d_22[0][0]']
#  tchNormalization)
#
#  dropout_5 (Dropout)         (None, 32, 32, 128)          0         ['batch_normalization_18[0][0]
#                                                                     ']
#
#  add_6 (Add)                 (None, 32, 32, 128)          0         ['batch_normalization_19[0][0]
#                                                                     ',
#                                                                      'dropout_5[0][0]']
#
#  activation_14 (Activation)  (None, 32, 32, 128)          0         ['add_6[0][0]']
#
#  conv2d_23 (Conv2D)          (None, 32, 32, 64)           8256      ['activation_14[0][0]']
#
#  batch_normalization_20 (Ba  (None, 32, 32, 64)           256       ['conv2d_23[0][0]']
#  tchNormalization)
#
#  activation_15 (Activation)  (None, 32, 32, 64)           0         ['batch_normalization_20[0][0]
#                                                                     ']
#
#  conv2d_25 (Conv2D)          (None, 32, 32, 64)           4160      ['activation_15[0][0]']
#
#  conv2d_transpose_1 (Conv2D  (None, 32, 32, 64)           36928     ['conv2d_25[0][0]']
#  Transpose)
#
#  conv2d_24 (Conv2D)          (None, 32, 32, 64)           16448     ['activation_5[0][0]']
#
#  add_7 (Add)                 (None, 32, 32, 64)           0         ['conv2d_transpose_1[0][0]',
#                                                                      'conv2d_24[0][0]']
#
#  activation_16 (Activation)  (None, 32, 32, 64)           0         ['add_7[0][0]']
#
#  conv2d_26 (Conv2D)          (None, 32, 32, 1)            65        ['activation_16[0][0]']
#
#  activation_17 (Activation)  (None, 32, 32, 1)            0         ['conv2d_26[0][0]']
#
#  up_sampling2d_2 (UpSamplin  (None, 64, 64, 1)            0         ['activation_17[0][0]']
#  g2D)
#
#  lambda_1 (Lambda)           (None, 64, 64, 64)           0         ['up_sampling2d_2[0][0]']
#
#  multiply_1 (Multiply)       (None, 64, 64, 64)           0         ['lambda_1[0][0]',
#                                                                      'activation_5[0][0]']
#
#  conv2d_27 (Conv2D)          (None, 64, 64, 64)           4160      ['multiply_1[0][0]']
#
#  up_sampling2d_3 (UpSamplin  (None, 64, 64, 128)          0         ['activation_14[0][0]']
#  g2D)
#
#  batch_normalization_21 (Ba  (None, 64, 64, 64)           256       ['conv2d_27[0][0]']
#  tchNormalization)
#
#  concatenate_1 (Concatenate  (None, 64, 64, 192)          0         ['up_sampling2d_3[0][0]',
#  )                                                                   'batch_normalization_21[0][0]
#                                                                     ']
#
#  conv2d_28 (Conv2D)          (None, 64, 64, 64)           110656    ['concatenate_1[0][0]']
#
#  batch_normalization_22 (Ba  (None, 64, 64, 64)           256       ['conv2d_28[0][0]']
#  tchNormalization)
#
#  activation_18 (Activation)  (None, 64, 64, 64)           0         ['batch_normalization_22[0][0]
#                                                                     ']
#
#  conv2d_29 (Conv2D)          (None, 64, 64, 64)           36928     ['activation_18[0][0]']
#
#  conv2d_30 (Conv2D)          (None, 64, 64, 64)           12352     ['concatenate_1[0][0]']
#
#  batch_normalization_23 (Ba  (None, 64, 64, 64)           256       ['conv2d_29[0][0]']
#  tchNormalization)
#
#  batch_normalization_24 (Ba  (None, 64, 64, 64)           256       ['conv2d_30[0][0]']
#  tchNormalization)
#
#  dropout_6 (Dropout)         (None, 64, 64, 64)           0         ['batch_normalization_23[0][0]
#                                                                     ']
#
#  add_8 (Add)                 (None, 64, 64, 64)           0         ['batch_normalization_24[0][0]
#                                                                     ',
#                                                                      'dropout_6[0][0]']
#
#  activation_19 (Activation)  (None, 64, 64, 64)           0         ['add_8[0][0]']
#
#  conv2d_31 (Conv2D)          (None, 64, 64, 32)           2080      ['activation_19[0][0]']
#
#  batch_normalization_25 (Ba  (None, 64, 64, 32)           128       ['conv2d_31[0][0]']
#  tchNormalization)
#
#  activation_20 (Activation)  (None, 64, 64, 32)           0         ['batch_normalization_25[0][0]
#                                                                     ']
#
#  conv2d_33 (Conv2D)          (None, 64, 64, 32)           1056      ['activation_20[0][0]']
#
#  conv2d_transpose_2 (Conv2D  (None, 64, 64, 32)           9248      ['conv2d_33[0][0]']
#  Transpose)
#
#  conv2d_32 (Conv2D)          (None, 64, 64, 32)           4128      ['activation_3[0][0]']
#
#  add_9 (Add)                 (None, 64, 64, 32)           0         ['conv2d_transpose_2[0][0]',
#                                                                      'conv2d_32[0][0]']
#
#  activation_21 (Activation)  (None, 64, 64, 32)           0         ['add_9[0][0]']
#
#  conv2d_34 (Conv2D)          (None, 64, 64, 1)            33        ['activation_21[0][0]']
#
#  activation_22 (Activation)  (None, 64, 64, 1)            0         ['conv2d_34[0][0]']
#
#  up_sampling2d_4 (UpSamplin  (None, 128, 128, 1)          0         ['activation_22[0][0]']
#  g2D)
#
#  lambda_2 (Lambda)           (None, 128, 128, 32)         0         ['up_sampling2d_4[0][0]']
#
#  multiply_2 (Multiply)       (None, 128, 128, 32)         0         ['lambda_2[0][0]',
#                                                                      'activation_3[0][0]']
#
#  conv2d_35 (Conv2D)          (None, 128, 128, 32)         1056      ['multiply_2[0][0]']
#
#  up_sampling2d_5 (UpSamplin  (None, 128, 128, 64)         0         ['activation_19[0][0]']
#  g2D)
#
#  batch_normalization_26 (Ba  (None, 128, 128, 32)         128       ['conv2d_35[0][0]']
#  tchNormalization)
#
#  concatenate_2 (Concatenate  (None, 128, 128, 96)         0         ['up_sampling2d_5[0][0]',
#  )                                                                   'batch_normalization_26[0][0]
#                                                                     ']
#
#  conv2d_36 (Conv2D)          (None, 128, 128, 32)         27680     ['concatenate_2[0][0]']
#
#  batch_normalization_27 (Ba  (None, 128, 128, 32)         128       ['conv2d_36[0][0]']
#  tchNormalization)
#
#  activation_23 (Activation)  (None, 128, 128, 32)         0         ['batch_normalization_27[0][0]
#                                                                     ']
#
#  conv2d_37 (Conv2D)          (None, 128, 128, 32)         9248      ['activation_23[0][0]']
#
#  conv2d_38 (Conv2D)          (None, 128, 128, 32)         3104      ['concatenate_2[0][0]']
#
#  batch_normalization_28 (Ba  (None, 128, 128, 32)         128       ['conv2d_37[0][0]']
#  tchNormalization)
#
#  batch_normalization_29 (Ba  (None, 128, 128, 32)         128       ['conv2d_38[0][0]']
#  tchNormalization)
#
#  dropout_7 (Dropout)         (None, 128, 128, 32)         0         ['batch_normalization_28[0][0]
#                                                                     ']
#
#  add_10 (Add)                (None, 128, 128, 32)         0         ['batch_normalization_29[0][0]
#                                                                     ',
#                                                                      'dropout_7[0][0]']
#
#  activation_24 (Activation)  (None, 128, 128, 32)         0         ['add_10[0][0]']
#
#  conv2d_39 (Conv2D)          (None, 128, 128, 16)         528       ['activation_24[0][0]']
#
#  batch_normalization_30 (Ba  (None, 128, 128, 16)         64        ['conv2d_39[0][0]']
#  tchNormalization)
#
#  activation_25 (Activation)  (None, 128, 128, 16)         0         ['batch_normalization_30[0][0]
#                                                                     ']
#
#  conv2d_41 (Conv2D)          (None, 128, 128, 16)         272       ['activation_25[0][0]']
#
#  conv2d_transpose_3 (Conv2D  (None, 128, 128, 16)         2320      ['conv2d_41[0][0]']
#  Transpose)
#
#  conv2d_40 (Conv2D)          (None, 128, 128, 16)         1040      ['activation_1[0][0]']
#
#  add_11 (Add)                (None, 128, 128, 16)         0         ['conv2d_transpose_3[0][0]',
#                                                                      'conv2d_40[0][0]']
#
#  activation_26 (Activation)  (None, 128, 128, 16)         0         ['add_11[0][0]']
#
#  conv2d_42 (Conv2D)          (None, 128, 128, 1)          17        ['activation_26[0][0]']
#
#  activation_27 (Activation)  (None, 128, 128, 1)          0         ['conv2d_42[0][0]']
#
#  up_sampling2d_6 (UpSamplin  (None, 256, 256, 1)          0         ['activation_27[0][0]']
#  g2D)
#
#  lambda_3 (Lambda)           (None, 256, 256, 16)         0         ['up_sampling2d_6[0][0]']
#
#  multiply_3 (Multiply)       (None, 256, 256, 16)         0         ['lambda_3[0][0]',
#                                                                      'activation_1[0][0]']
#
#  conv2d_43 (Conv2D)          (None, 256, 256, 16)         272       ['multiply_3[0][0]']
#
#  up_sampling2d_7 (UpSamplin  (None, 256, 256, 32)         0         ['activation_24[0][0]']
#  g2D)
#
#  batch_normalization_31 (Ba  (None, 256, 256, 16)         64        ['conv2d_43[0][0]']
#  tchNormalization)
#
#  concatenate_3 (Concatenate  (None, 256, 256, 48)         0         ['up_sampling2d_7[0][0]',
#  )                                                                   'batch_normalization_31[0][0]
#                                                                     ']
#
#  conv2d_44 (Conv2D)          (None, 256, 256, 16)         6928      ['concatenate_3[0][0]']
#
#  batch_normalization_32 (Ba  (None, 256, 256, 16)         64        ['conv2d_44[0][0]']
#  tchNormalization)
#
#  activation_28 (Activation)  (None, 256, 256, 16)         0         ['batch_normalization_32[0][0]
#                                                                     ']
#
#  conv2d_45 (Conv2D)          (None, 256, 256, 16)         2320      ['activation_28[0][0]']
#
#  conv2d_46 (Conv2D)          (None, 256, 256, 16)         784       ['concatenate_3[0][0]']
#
#  batch_normalization_33 (Ba  (None, 256, 256, 16)         64        ['conv2d_45[0][0]']
#  tchNormalization)
#
#  batch_normalization_34 (Ba  (None, 256, 256, 16)         64        ['conv2d_46[0][0]']
#  tchNormalization)
#
#  dropout_8 (Dropout)         (None, 256, 256, 16)         0         ['batch_normalization_33[0][0]
#                                                                     ']
#
#  add_12 (Add)                (None, 256, 256, 16)         0         ['batch_normalization_34[0][0]
#                                                                     ',
#                                                                      'dropout_8[0][0]']
#
#  activation_29 (Activation)  (None, 256, 256, 16)         0         ['add_12[0][0]']
#
#  conv2d_47 (Conv2D)          (None, 256, 256, 6)          102       ['activation_29[0][0]']
#
#  batch_normalization_35 (Ba  (None, 256, 256, 6)          24        ['conv2d_47[0][0]']
#  tchNormalization)
#
#  activation_30 (Activation)  (None, 256, 256, 6)          0         ['batch_normalization_35[0][0]
#                                                                     ']
#
# ==================================================================================================
# Total params: 2454434 (9.36 MB)
# Trainable params: 2449046 (9.34 MB)
# Non-trainable params: 5388 (21.05 KB)
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.callbacks import ModelCheckpoint,EarlyStopping,ReduceLROnPlateau
model_filepath = "/content/drive/MyDrive/saved_models/atteresnunet.hdf5"
checkpoint = ModelCheckpoint(
    filepath=model_filepath,
    monitor='val_accuracy',
    mode='max',
    save_best_only=True,
    verbose=1
)
earlystop = EarlyStopping(
    monitor = 'val_loss',
    min_delta = 0.001,
    patience = 15,
    mode = 'auto',
    verbose = 1,
    restore_best_weights = True
)
redr = ReduceLROnPlateau(factor=0.5, patience=10, min_lr=1e-6)

# %%
model_history = model.fit(X_train, y_train,
                          batch_size=8,  # Adjust batch size
                          verbose=1,
                          epochs=100,
                          validation_data=(X_test, y_test),
                          callbacks=[checkpoint],
                          shuffle=False)
# Out:
# Epoch 1/100
# 50/50 [==============================] - ETA: 0s - loss: 0.3552 - accuracy: 0.9002 - jacard_coef: 0.6534 - precision: 0.9191 - recall: 0.8787 - f1: 0.8984
# Epoch 1: val_accuracy did not improve from 0.83252
# 50/50 [==============================] -
100
# 50/50 [==============================] - ETA: 0s - loss: 0.0793 - accuracy: 0.9709 - jacard_coef: 0.9081 - precision: 0.9723 - recall: 0.9695 - f1: 0.9709
# Epoch 98: val_accuracy did not improve from 0.84804
# 50/50 [==============================] - 11s 217ms/step - loss: 0.0793 - accuracy: 0.9709 - jacard_coef: 0.9081 - precision: 0.9723 - recall: 0.9695 - f1: 0.9709 - val_loss: 0.6926 - val_accuracy: 0.8335 - val_jacard_coef: 0.7026 - val_precision: 0.8414 - val_recall: 0.8361 - val_f1: 0.8388
# Epoch 99/100
# 50/50 [==============================] - ETA: 0s - loss: 0.0766 - accuracy: 0.9715 - jacard_coef: 0.9111 - precision: 0.9729 - recall: 0.9703 - f1: 0.9716
# Epoch 99: val_accuracy did not improve from 0.84804
# 50/50 [==============================] - 11s 220ms/step - loss: 0.0766 - accuracy: 0.9715 - jacard_coef: 0.9111 - precision: 0.9729 - recall: 0.9703 - f1: 0.9716 - val_loss: 0.6716 - val_accuracy: 0.8410 - val_jacard_coef: 0.7156 - val_precision: 0.8486 - val_recall: 0.8434 - val_f1: 0.8460
# Epoch 100/100
# 50/50 [==============================] - ETA: 0s - loss: 0.0743 - accuracy: 0.9724 - jacard_coef: 0.9136 - precision: 0.9737 - recall: 0.9711 - f1: 0.9724
# Epoch 100: val_accuracy did not improve from 0.84804
# 50/50 [==============================] - 11s 218ms/step - loss: 0.0743 - accuracy: 0.9724 - jacard_coef: 0.9136 - precision: 0.9737 - recall: 0.9711 - f1: 0.9724 - val_loss: 0.6769 - val_accuracy: 0.8443 - val_jacard_coef: 0.7212 - val_precision: 0.8514 - val_recall: 0.8472 - val_f1: 0.8493

# %%
history_a = model_history

# %%
loss = history_a.history['loss']
val_loss = history_a.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label="Training Loss")
plt.plot(epochs, val_loss, 'r', label="Validation Loss")
plt.title("Training Vs Validation Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %%
jacard_coef = history_a.history['jacard_coef']
val_jacard_coef = history_a.history['val_jacard_coef']

epochs = range(1, len(jacard_coef) + 1)
plt.plot(epochs, jacard_coef, 'y', label="Training IoU")
plt.plot(epochs, val_jacard_coef, 'r', label="Validation IoU")
plt.title("Training Vs Validation IoU")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %%
import random
y_test_argmax = np.argmax(y_test, axis=3)

# %%
test_image_number = random.randint(0, len(X_test))

test_image = X_test[test_image_number]
ground_truth_image = y_test_argmax[test_image_number]

test_image_input = np.expand_dims(test_image, 0)

prediction = model.predict(test_image_input)
predicted_image = np.argmax(prediction, axis=3)
predicted_image = predicted_image[0,:,:]
# Out:
# 1/1 [==============================] - 0s 33ms/step

# %%
plt.figure(figsize=(14,8))
plt.subplot(231)
plt.title("Original Image")
plt.imshow(test_image)
plt.subplot(232)
plt.title("Original Masked image")
plt.imshow(ground_truth_image)
plt.subplot(233)
plt.title("Predicted Image")
plt.imshow(predicted_image)

# %%
y_pred=model.predict(X_test)
y_pred_argmax=np.argmax(y_pred, axis=3)
# Out:
# 4/4 [==============================] - 1s 160ms/step

# %%
from sklearn.metrics import classification_report

# Assuming y_pred_argmax contains the predicted class indices
# Compute precision, recall, and F1 score
print(classification_report(y_test_argmax.flatten(), y_pred_argmax.flatten()))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.87      0.98      0.92   1399826
#            1       0.83      0.88      0.85   3010573
#            2       0.75      0.67      0.71    667582
#            3       0.76      0.71      0.73    619406
#            4       0.93      0.71      0.80    790499
#            5       0.00      0.00      0.00     65714
#
#     accuracy                           0.83   6553600
#    macro avg       0.69      0.66      0.67   6553600
# weighted avg       0.82      0.83      0.83   6553600
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
